# %%
import matplotlib
print(matplotlib.__version__)
# Out:
# 3.10.0

# %%
# Most of the matplotlib utilities are under the pyplot submodule and are usually imported under the plt alias
import matplotlib.pyplot as plt
import numpy as np

# %%
x_points = np.array([0, 10])
y_points = np.array([0, 250])

print(x_points)

plt.plot(x_points, y_points)
plt.show()
# Out:
# [ 0 10]
